# %%
#Access/Read File
file_location = "/FileStore/tables/son"

df = spark.read.option("multiline", True) \
  .json(file_location)

display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>meta</th><th>results</th></tr></thead><tbody><tr><td>List(408, 1000, openaq-api, 1, /)</td><td>List(List(List(-114.449722, 53.493889, -114.449722, 53.493889), List(53.493889, -114.449722), List(CA, 156, Canada), List(2016-03-10T01:00:00-07:00, 2016-03-10T08:00:00Z), List(2024-12-06T19:00:00-07:00, 2024-12-07T02:00:00Z), null, 285, List(List(2, Government Monitor)), false, true, List(List(List(Unknown Governmental Organization, null), 2016-01-30, null, 33, US Public Domain)), ALBERTA, Wagner2, List(4, Unknown Governmental Organization), List(119, AirNow), List(List(473, no2 ppm, List(NO₂, 7, no2, ppm)), List(472, so2 ppm, List(SO₂, 9, so2, ppm))), America/Edmonton), List(List(-111.50264, 54.216473, -111.50264, 54.216473), List(54.216473, -111.50264), List(CA, 156, Canada), List(2016-03-10T01:00:00-07:00, 2016-03-10T08:00:00Z), List(2024-12-06T19:00:00-07:00, 2024-12-07T02:00:00Z), null, 287, List(List(2, Government Monitor)), false, true, List(List(List(Unknown Governmental Organization, null), 2016-01-30, null, 33, US Public Domain)), ALBERTA, St. Lina, List(4, Unknown Governmental Organization), List(119, AirNow), List(List(477, no2 ppm, List(NO₂, 7, no2, ppm)), List(476, o3 ppm, List(O₃, 10, o3, ppm)), List(500, pm25 µg/m³, List(PM2.5, 2, pm25, µg/m³)), List(475, so2 ppm, List(SO₂, 9, so2, ppm))), America/Edmonton), List(List(-117.09111, 53.1325, -117.09111, 53.1325), List(53.1325, -117.09111), List(CA, 156, Canada), List(2016-03-10T01:00:00-07:00, 2016-03-10T08:00:00Z), List(2024-12-06T19:00:00-07:00, 2024-12-07T02:00:00Z), null, 297, List(List(2, Government Monitor)), false, true, List(List(List(Unknown Governmental Organization, null), 2016-01-30, null, 33, US Public Domain)), ALBERTA, Steeper, List(4, Unknown Governmental Organization), List(119, AirNow), List(List(498, no2 ppm, List(NO₂, 7, no2, ppm)), List(497, o3 ppm, List(O₃, 10, o3, ppm)), List(502, pm25 µg/m³, List(PM2.5, 2, pm25, µg/m³)), List(495, so2 ppm, List(SO₂, 9, so2, ppm))), America/Edmonton), List(List(-112.927795, 53.800117, -112.927795, 53.800117), List(53.800117, -112.927795), List(CA, 156, Canada), List(2016-03-10T01:00:00-07:00, 2016-03-10T08:00:00Z), List(2024-12-06T14:00:00-07:00, 2024-12-06T21:00:00Z), null, 298, List(List(2, Government Monitor)), false, true, List(List(List(Unknown Governmental Organization, null), 2016-01-30, null, 33, US Public Domain)), ALBERTA, Bruderheim, List(4, Unknown Governmental Organization), List(119, AirNow), List(List(496, no2 ppm, List(NO₂, 7, no2, ppm)), List(499, o3 ppm, List(O₃, 10, o3, ppm)), List(503, pm25 µg/m³, List(PM2.5, 2, pm25, µg/m³)), List(501, so2 ppm, List(SO₂, 9, so2, ppm))), America/Edmonton), List(List(-123.1544, 49.7064, -123.1544, 49.7064), List(49.7064, -123.1544), List(CA, 156, Canada), List(2016-03-10T00:00:00-08:00, 2016-03-10T08:00:00Z), List(2016-04-19T20:00:00-07:00, 2016-04-20T03:00:00Z), null, 307, List(List(2, Government Monitor)), false, true, List(List(List(Unknown Governmental Organization, null), 2016-01-30, null, 33, US Public Domain)), null, Squamish, List(4, Unknown Governmental Organization), List(119, AirNow), List(List(520, o3 ppm, List(O₃, 10, o3, ppm))), America/Vancouver), List(List(-111.4761, 56.7522, -111.4761, 56.7522), List(56.7522, -111.4761), List(CA, 156, Canada), List(2016-03-10T01:00:00-07:00, 2016-03-10T08:00:00Z), List(2024-12-06T19:00:00-07:00, 2024-12-07T02:00:00Z), null, 360, List(List(2, Government Monitor)), false, true, List(List(List(Unknown Governmental Organization, null), 2016-01-30, null, 33, US Public Domain)), ALBERTA, Patricia McInnes, List(4, Unknown Governmental Organization), List(119, AirNow), List(List(751, o3 ppm, List(O₃, 10, o3, ppm)), List(616, pm25 µg/m³, List(PM2.5, 2, pm25, µg/m³))), America/Edmonton), List(List(-116.509953, 48.995911, -116.509953, 48.995911), List(48.995911, -116.509953), List(CA, 156, Canada), List(20 ...

# %%
#Imports

from pyspark.sql.functions import from_json, col,explode,posexplode
from pyspark.sql.types import StructType, StructField, StringType

# %% [markdown]
# RULE IF I WANT TO FLATTERM THE JSON FILE
#
#
# 0. DON'T GET EXCITED
# 1. NOTE ALL COLUMN YOU WANT
# 2. NOTE EVERY ARRAY YOU WANT TO EXPLODE FROM SCHEMA USING : withColumn('aliasName',explode('structurename.arrayname'))
# 3. SELECT EVERYTHING YOU WANT BY USING THE NOTES FROM POINT 1.
# 4. CELEBRATE

# %%
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>meta</th><th>results</th></tr></thead><tbody><tr><td>List(408, 1000, openaq-api, 1, /)</td><td>List(List(List(-114.449722, 53.493889, -114.449722, 53.493889), List(53.493889, -114.449722), List(CA, 156, Canada), List(2016-03-10T01:00:00-07:00, 2016-03-10T08:00:00Z), List(2024-12-06T19:00:00-07:00, 2024-12-07T02:00:00Z), null, 285, List(List(2, Government Monitor)), false, true, List(List(List(Unknown Governmental Organization, null), 2016-01-30, null, 33, US Public Domain)), ALBERTA, Wagner2, List(4, Unknown Governmental Organization), List(119, AirNow), List(List(473, no2 ppm, List(NO₂, 7, no2, ppm)), List(472, so2 ppm, List(SO₂, 9, so2, ppm))), America/Edmonton), List(List(-111.50264, 54.216473, -111.50264, 54.216473), List(54.216473, -111.50264), List(CA, 156, Canada), List(2016-03-10T01:00:00-07:00, 2016-03-10T08:00:00Z), List(2024-12-06T19:00:00-07:00, 2024-12-07T02:00:00Z), null, 287, List(List(2, Government Monitor)), false, true, List(List(List(Unknown Governmental Organization, null), 2016-01-30, null, 33, US Public Domain)), ALBERTA, St. Lina, List(4, Unknown Governmental Organization), List(119, AirNow), List(List(477, no2 ppm, List(NO₂, 7, no2, ppm)), List(476, o3 ppm, List(O₃, 10, o3, ppm)), List(500, pm25 µg/m³, List(PM2.5, 2, pm25, µg/m³)), List(475, so2 ppm, List(SO₂, 9, so2, ppm))), America/Edmonton), List(List(-117.09111, 53.1325, -117.09111, 53.1325), List(53.1325, -117.09111), List(CA, 156, Canada), List(2016-03-10T01:00:00-07:00, 2016-03-10T08:00:00Z), List(2024-12-06T19:00:00-07:00, 2024-12-07T02:00:00Z), null, 297, List(List(2, Government Monitor)), false, true, List(List(List(Unknown Governmental Organization, null), 2016-01-30, null, 33, US Public Domain)), ALBERTA, Steeper, List(4, Unknown Governmental Organization), List(119, AirNow), List(List(498, no2 ppm, List(NO₂, 7, no2, ppm)), List(497, o3 ppm, List(O₃, 10, o3, ppm)), List(502, pm25 µg/m³, List(PM2.5, 2, pm25, µg/m³)), List(495, so2 ppm, List(SO₂, 9, so2, ppm))), America/Edmonton), List(List(-112.927795, 53.800117, -112.927795, 53.800117), List(53.800117, -112.927795), List(CA, 156, Canada), List(2016-03-10T01:00:00-07:00, 2016-03-10T08:00:00Z), List(2024-12-06T14:00:00-07:00, 2024-12-06T21:00:00Z), null, 298, List(List(2, Government Monitor)), false, true, List(List(List(Unknown Governmental Organization, null), 2016-01-30, null, 33, US Public Domain)), ALBERTA, Bruderheim, List(4, Unknown Governmental Organization), List(119, AirNow), List(List(496, no2 ppm, List(NO₂, 7, no2, ppm)), List(499, o3 ppm, List(O₃, 10, o3, ppm)), List(503, pm25 µg/m³, List(PM2.5, 2, pm25, µg/m³)), List(501, so2 ppm, List(SO₂, 9, so2, ppm))), America/Edmonton), List(List(-123.1544, 49.7064, -123.1544, 49.7064), List(49.7064, -123.1544), List(CA, 156, Canada), List(2016-03-10T00:00:00-08:00, 2016-03-10T08:00:00Z), List(2016-04-19T20:00:00-07:00, 2016-04-20T03:00:00Z), null, 307, List(List(2, Government Monitor)), false, true, List(List(List(Unknown Governmental Organization, null), 2016-01-30, null, 33, US Public Domain)), null, Squamish, List(4, Unknown Governmental Organization), List(119, AirNow), List(List(520, o3 ppm, List(O₃, 10, o3, ppm))), America/Vancouver), List(List(-111.4761, 56.7522, -111.4761, 56.7522), List(56.7522, -111.4761), List(CA, 156, Canada), List(2016-03-10T01:00:00-07:00, 2016-03-10T08:00:00Z), List(2024-12-06T19:00:00-07:00, 2024-12-07T02:00:00Z), null, 360, List(List(2, Government Monitor)), false, true, List(List(List(Unknown Governmental Organization, null), 2016-01-30, null, 33, US Public Domain)), ALBERTA, Patricia McInnes, List(4, Unknown Governmental Organization), List(119, AirNow), List(List(751, o3 ppm, List(O₃, 10, o3, ppm)), List(616, pm25 µg/m³, List(PM2.5, 2, pm25, µg/m³))), America/Edmonton), List(List(-116.509953, 48.995911, -116.509953, 48.995911), List(48.995911, -116.509953), List(CA, 156, Canada), List(20 ...

# %%
temp_df = df.withColumn("results",explode('results'))\
            .select("results.")

display(temp_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>meta</th><th>results</th></tr></thead><tbody><tr><td>List(408, 1000, openaq-api, 1, /)</td><td>List(List(-114.449722, 53.493889, -114.449722, 53.493889), List(53.493889, -114.449722), List(CA, 156, Canada), List(2016-03-10T01:00:00-07:00, 2016-03-10T08:00:00Z), List(2024-12-06T19:00:00-07:00, 2024-12-07T02:00:00Z), null, 285, List(List(2, Government Monitor)), false, true, List(List(List(Unknown Governmental Organization, null), 2016-01-30, null, 33, US Public Domain)), ALBERTA, Wagner2, List(4, Unknown Governmental Organization), List(119, AirNow), List(List(473, no2 ppm, List(NO₂, 7, no2, ppm)), List(472, so2 ppm, List(SO₂, 9, so2, ppm))), America/Edmonton)</td></tr><tr><td>List(408, 1000, openaq-api, 1, /)</td><td>List(List(-111.50264, 54.216473, -111.50264, 54.216473), List(54.216473, -111.50264), List(CA, 156, Canada), List(2016-03-10T01:00:00-07:00, 2016-03-10T08:00:00Z), List(2024-12-06T19:00:00-07:00, 2024-12-07T02:00:00Z), null, 287, List(List(2, Government Monitor)), false, true, List(List(List(Unknown Governmental Organization, null), 2016-01-30, null, 33, US Public Domain)), ALBERTA, St. Lina, List(4, Unknown Governmental Organization), List(119, AirNow), List(List(477, no2 ppm, List(NO₂, 7, no2, ppm)), List(476, o3 ppm, List(O₃, 10, o3, ppm)), List(500, pm25 µg/m³, List(PM2.5, 2, pm25, µg/m³)), List(475, so2 ppm, List(SO₂, 9, so2, ppm))), America/Edmonton)</td></tr><tr><td>List(408, 1000, openaq-api, 1, /)</td><td>List(List(-117.09111, 53.1325, -117.09111, 53.1325), List(53.1325, -117.09111), List(CA, 156, Canada), List(2016-03-10T01:00:00-07:00, 2016-03-10T08:00:00Z), List(2024-12-06T19:00:00-07:00, 2024-12-07T02:00:00Z), null, 297, List(List(2, Government Monitor)), false, true, List(List(List(Unknown Governmental Organization, null), 2016-01-30, null, 33, US Public Domain)), ALBERTA, Steeper, List(4, Unknown Governmental Organization), List(119, AirNow), List(List(498, no2 ppm, List(NO₂, 7, no2, ppm)), List(497, o3 ppm, List(O₃, 10, o3, ppm)), List(502, pm25 µg/m³, List(PM2.5, 2, pm25, µg/m³)), List(495, so2 ppm, List(SO₂, 9, so2, ppm))), America/Edmonton)</td></tr><tr><td>List(408, 1000, openaq-api, 1, /)</td><td>List(List(-112.927795, 53.800117, -112.927795, 53.800117), List(53.800117, -112.927795), List(CA, 156, Canada), List(2016-03-10T01:00:00-07:00, 2016-03-10T08:00:00Z), List(2024-12-06T14:00:00-07:00, 2024-12-06T21:00:00Z), null, 298, List(List(2, Government Monitor)), false, true, List(List(List(Unknown Governmental Organization, null), 2016-01-30, null, 33, US Public Domain)), ALBERTA, Bruderheim, List(4, Unknown Governmental Organization), List(119, AirNow), List(List(496, no2 ppm, List(NO₂, 7, no2, ppm)), List(499, o3 ppm, List(O₃, 10, o3, ppm)), List(503, pm25 µg/m³, List(PM2.5, 2, pm25, µg/m³)), List(501, so2 ppm, List(SO₂, 9, so2, ppm))), America/Edmonton)</td></tr><tr><td>List(408, 1000, openaq-api, 1, /)</td><td>List(List(-123.1544, 49.7064, -123.1544, 49.7064), List(49.7064, -123.1544), List(CA, 156, Canada), List(2016-03-10T00:00:00-08:00, 2016-03-10T08:00:00Z), List(2016-04-19T20:00:00-07:00, 2016-04-20T03:00:00Z), null, 307, List(List(2, Government Monitor)), false, true, List(List(List(Unknown Governmental Organization, null), 2016-01-30, null, 33, US Public Domain)), null, Squamish, List(4, Unknown Governmental Organization), List(119, AirNow), List(List(520, o3 ppm, List(O₃, 10, o3, ppm))), America/Vancouver)</td></tr><tr><td>List(408, 1000, openaq-api, 1, /)</td><td>List(List(-111.4761, 56.7522, -111.4761, 56.7522), List(56.7522, -111.4761), List(CA, 156, Canada), List(2016-03-10T01:00:00-07:00, 2016-03-10T08:00:00Z), List(2024-12-06T19:00:00-07:00, 2024-12-07T02:00:00Z), null, 360, List(List(2, Government Monitor)), false, true, List(List(List(Unknown Governmental Organization, null), 2016-01-30, null, 33, US Public Domain)), ALBERTA, Patricia McInnes, List(4, Unknown  ...

# %%
#flattning JSON File

new_df = df.withColumn("new_results",explode('results'))\
    .withColumn('sensor', explode('new_results.sensors'))\
    .select('*','new_results.coordinates.latitude','new_results.coordinates.longitude','sensor.id','sensor.name')\
    .drop('meta').drop('results').drop('new_results').drop('sensor')
display(new_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>latitude</th><th>longitude</th><th>id</th><th>name</th></tr></thead><tbody><tr><td>53.493889</td><td>-114.449722</td><td>473</td><td>no2 ppm</td></tr><tr><td>53.493889</td><td>-114.449722</td><td>472</td><td>so2 ppm</td></tr><tr><td>54.216473</td><td>-111.50264</td><td>477</td><td>no2 ppm</td></tr><tr><td>54.216473</td><td>-111.50264</td><td>476</td><td>o3 ppm</td></tr><tr><td>54.216473</td><td>-111.50264</td><td>500</td><td>pm25 µg/m³</td></tr><tr><td>54.216473</td><td>-111.50264</td><td>475</td><td>so2 ppm</td></tr><tr><td>53.1325</td><td>-117.09111</td><td>498</td><td>no2 ppm</td></tr><tr><td>53.1325</td><td>-117.09111</td><td>497</td><td>o3 ppm</td></tr><tr><td>53.1325</td><td>-117.09111</td><td>502</td><td>pm25 µg/m³</td></tr><tr><td>53.1325</td><td>-117.09111</td><td>495</td><td>so2 ppm</td></tr><tr><td>53.800117</td><td>-112.927795</td><td>496</td><td>no2 ppm</td></tr><tr><td>53.800117</td><td>-112.927795</td><td>499</td><td>o3 ppm</td></tr><tr><td>53.800117</td><td>-112.927795</td><td>503</td><td>pm25 µg/m³</td></tr><tr><td>53.800117</td><td>-112.927795</td><td>501</td><td>so2 ppm</td></tr><tr><td>49.7064</td><td>-123.1544</td><td>520</td><td>o3 ppm</td></tr><tr><td>56.7522</td><td>-111.4761</td><td>751</td><td>o3 ppm</td></tr><tr><td>56.7522</td><td>-111.4761</td><td>616</td><td>pm25 µg/m³</td></tr><tr><td>48.995911</td><td>-116.509953</td><td>652</td><td>pm25 µg/m³</td></tr><tr><td>53.6825</td><td>-112.8686</td><td>846</td><td>o3 ppm</td></tr><tr><td>53.6825</td><td>-112.8686</td><td>669</td><td>pm25 µg/m³</td></tr><tr><td>52.2989</td><td>-113.7942</td><td>809</td><td>o3 ppm</td></tr><tr><td>52.2989</td><td>-113.7942</td><td>680</td><td>pm25 µg/m³</td></tr><tr><td>53.5936</td><td>-116.39280000000001</td><td>685</td><td>no2 ppm</td></tr><tr><td>53.5936</td><td>-116.39280000000001</td><td>687</td><td>o3 ppm</td></tr><tr><td>53.5936</td><td>-116.39280000000001</td><td>1582665</td><td>pm25 µg/m³</td></tr><tr><td>45.3656</td><td>-72.2656</td><td>716</td><td>o3 ppm</td></tr><tr><td>51.6667</td><td>-110.2</td><td>717</td><td>o3 ppm</td></tr><tr><td>46.3864</td><td>-62.5828</td><td>5077585</td><td>no ppm</td></tr><tr><td>46.3864</td><td>-62.5828</td><td>5077823</td><td>no2 ppm</td></tr><tr><td>46.3864</td><td>-62.5828</td><td>5077645</td><td>o3 ppm</td></tr><tr><td>46.3864</td><td>-62.5828</td><td>5077847</td><td>pm25 µg/m³</td></tr><tr><td>45.7228</td><td>-73.3764</td><td>757</td><td>o3 ppm</td></tr><tr><td>46.035</td><td>-74.4819</td><td>759</td><td>o3 ppm</td></tr><tr><td>46.035</td><td>-74.4819</td><td>760</td><td>pm25 µg/m³</td></tr><tr><td>45.6481</td><td>-73.4997</td><td>762</td><td>o3 ppm</td></tr><tr><td>45.8156</td><td>-70.8597</td><td>774</td><td>o3 ppm</td></tr><tr><td>45.8156</td><td>-70.8597</td><td>1356932</td><td>pm25 µg/m³</td></tr><tr><td>48.8183</td><td>-72.7428</td><td>780</td><td>o3 ppm</td></tr><tr><td>48.8183</td><td>-72.7428</td><td>1356914</td><td>pm25 µg/m³</td></tr><tr><td>45.5231</td><td>-73.4939</td><td>788</td><td>o3 ppm</td></tr><tr><td>45.5231</td><td>-73.4939</td><td>1356910</td><td>pm25 µg/m³</td></tr><tr><td>55.1964</td><td>-119.3967</td><td>796</td><td>o3 ppm</td></tr><tr><td>55.1964</td><td>-119.3967</td><td>791</td><td>pm25 µg/m³</td></tr><tr><td>53.1422</td><td>-115.1381</td><td>798</td><td>o3 ppm</td></tr><tr><td>45.6569</td><td>-73.575</td><td>801</td><td>no2 ppm</td></tr><tr><td>45.6569</td><td>-73.575</td><td>800</td><td>o3 ppm</td></tr><tr><td>45.3733</td><td>-71.2514</td><td>810</td><td>o3 ppm</td></tr><tr><td>45.3733</td><td>-71.2514</td><td>1356912</td><td>pm25 µg/m³</td></tr><tr><td>45.4431</td><td>-73.4686</td><td>812</td><td>o3 ppm</td></tr><tr><td>45.4431</td><td>-73.4686</td><td>1356924</td><td>pm25 µg/m³</td></tr><tr><td>48.2344</td><td>-78.9833</td><td>821</td><td>o3 ppm</td></tr><tr><td>48.2344</td><td>-78.9833</td><td>1356925</td><td>pm25 µg/m³</td></tr ...

# %%
new_df
# Out:
# Out[42]: DataFrame[latitude: double, longitude: double, id: bigint, name: string]

# %%
jdbc_url = "jdbc:sqlserver://riyaldbsrvr.database.windows.net:1433;database=dbAssignment1" # JDBC url 
table_name = "CanadaSensors"
connection_properties = {
    "user": "username@dbserver", # db User name
    "password": "password@123", # db Password
    "driver": "com.microsoft.sqlserver.jdbc.SQLServerDriver"
}

# %%
new_df.write.jdbc(url=jdbc_url, table=table_name, mode="overwrite", properties=connection_properties)
